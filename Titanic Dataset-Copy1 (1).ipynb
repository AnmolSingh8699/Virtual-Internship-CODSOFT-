# %%
import numpy as np
import pandas as pd

# %%
cd = pd.read_csv('Titanic-Dataset.csv')

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
cd.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
cd.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
cd.iloc()

# %%
cd.loc()

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
cd = cd.drop([2,3], axis=0)

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 0        0   A/5 21171   7.2500   NaN        S
# 1        0    PC 17599  71.2833   C85        C
# 4        0      373450   8.0500   NaN        S
# 5        0      330877   8.4583   NaN        Q
# 6        0       17463  51.8625   E46        S
# ..     ...         ...      ...   ...      ...
# 886      0      211536  13.0000   NaN        S
# 887      0      112053  30.0000   B42        S
# 888      2  W./C. 6607  23.4500   NaN        S
# 889      0      111369  30.0000  C148        C
# 890      0      370376   7.7500   NaN        Q
#
# [889 rows x 12 columns]

# %%
(len(cd.columns))
# to count number of columns only
# Out:
# 12

# %%
(len(cd))
# to count number of rows only
# Out:
# 889

# %%
cd.shape
# to find no. of rows and columns at same time
# Out:
# (889, 12)

# %%
cd.size
# multiplies rows and columns together
# Out:
# 10668

# %%
cd.describe()
# to count mean  , max , min , std
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  712.000000  889.000000
# mean    446.995501    0.382452    2.309336   29.696868    0.523060
# std     256.784289    0.486260    0.835537   14.544894    1.103729
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     225.000000    0.000000    2.000000   20.000000    0.000000
# 50%     447.000000    0.000000    3.000000   28.000000    0.000000
# 75%     669.000000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.208014
# std      0.806761   49.737743
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Create the heatmap to check missing values

sns.heatmap(cd.corr(), annot=True, fmt='.1f')
plt.title('missing values')
plt.xlabel('Columns Name')
plt.ylabel('Average of Missing Values')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_968\4234870770.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cd.corr(), annot=True, fmt='.1f')

# %%
Embarked = pd.get_dummies(cd['Embarked'],drop_first=True)
# creating dummies

# %%
cd.drop([ 'Embarked'],axis=1,inplace=True)
# this will help to drop columns with name sex and embarked

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin
# 0        0   A/5 21171   7.2500   NaN
# 1        0    PC 17599  71.2833   C85
# 4        0      373450   8.0500   NaN
# 5        0      330877   8.4583   NaN
# 6        0       17463  51.8625   E46
# ..     ...         ...      ...   ...
# 886      0      211536  13.0000   NaN
# 887      0      112053  30.0000   B42
# 888      2  W./C. 6607  23.4500   NaN
# 889      0      111369  30.0000  C148
# 890      0      370376   7.7500   NaN
#
# [889 rows x 11 columns]

# %%
# %matplotlib inline 
# to properly arrange columns

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin
# 0        0   A/5 21171   7.2500   NaN
# 1        0    PC 17599  71.2833   C85
# 4        0      373450   8.0500   NaN
# 5        0      330877   8.4583   NaN
# 6        0       17463  51.8625   E46
# ..     ...         ...      ...   ...
# 886      0      211536  13.0000   NaN
# 887      0      112053  30.0000   B42
# 888      2  W./C. 6607  23.4500   NaN
# 889      0      111369  30.0000  C148
# 890      0      370376   7.7500   NaN
#
# [889 rows x 11 columns]

# %%
cd = pd.concat([cd,Embarked],axis=1)

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin  Q  S
# 0        0   A/5 21171   7.2500   NaN  0  1
# 1        0    PC 17599  71.2833   C85  0  0
# 4        0      373450   8.0500   NaN  0  1
# 5        0      330877   8.4583   NaN  1  0
# 6        0       17463  51.8625   E46  0  1
# ..     ...         ...      ...   ... .. ..
# 886      0      211536  13.0000   NaN  0  1
# 887      0      112053  30.0000   B42  0  1
# 888      2  W./C. 6607  23.4500   NaN  0  1
# 889      0      111369  30.0000  C148  0  0
# 890      0      370376   7.7500   NaN  1  0
#
# [889 rows x 13 columns]

# %%
cd['Female'] = (cd['Sex'] == 'female').astype(int)

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin  Q  S  Female
# 0        0   A/5 21171   7.2500   NaN  0  1       0
# 1        0    PC 17599  71.2833   C85  0  0       1
# 4        0      373450   8.0500   NaN  0  1       0
# 5        0      330877   8.4583   NaN  1  0       0
# 6        0       17463  51.8625   E46  0  1       0
# ..     ...         ...      ...   ... .. ..     ...
# 886      0      211536  13.0000   NaN  0  1       0
# 887      0      112053  30.0000   B42  0  1       1
# 888      2  W./C. 6607  23.4500   NaN  0  1       1
# 889      0      111369  30.0000  C148  0  0       0
# 890      0      370376   7.7500   NaN  1  0       0
#
# [889 rows x 14 columns]

# %%
cd['Male'] = (cd['Sex'] == 'female').astype(int)

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin  Q  S  Female  Male
# 0        0   A/5 21171   7.2500   NaN  0  1       0     0
# 1        0    PC 17599  71.2833   C85  0  0       1     1
# 4        0      373450   8.0500   NaN  0  1       0     0
# 5        0      330877   8.4583   NaN  1  0       0     0
# 6        0       17463  51.8625   E46  0  1       0     0
# ..     ...         ...      ...   ... .. ..     ...   ...
# 886      0      211536  13.0000   NaN  0  1       0     0
# 887      0      112053  30.0000   B42  0  1       1     1
# 888      2  W./C. 6607  23.4500   NaN  0  1       1     1
# 889      0      111369  30.0000  C148  0  0       0     0
# 890      0      370376   7.7500   NaN  1  0       0     0
#
# [889 rows x 15 columns]

# %%
sns.countplot(x = 'Survived' , data=cd)
# bar graph to show no.of survived and unsurvived
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Pclass' , data=cd)
# bar graph to show counting of different type of passenger class
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x = 'Survived' , data=cd ,hue='Male')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Survived' , data=cd ,hue='Female')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
plt.hist(cd['Fare'], bins = 50)
plt.title("Fare Distribution")
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
cd.Ticket.value_counts()
# Out:
# CA. 2343    7
# 1601        7
# 347082      7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 680, dtype: int64

# %%
cd
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare Cabin  Q  S  Female  Male
# 0        0   A/5 21171   7.2500   NaN  0  1       0     0
# 1        0    PC 17599  71.2833   C85  0  0       1     1
# 4        0      373450   8.0500   NaN  0  1       0     0
# 5        0      330877   8.4583   NaN  1  0       0     0
# 6        0       17463  51.8625   E46  0  1       0     0
# ..     ...         ...      ...   ... .. ..     ...   ...
# 886      0      211536  13.0000   NaN  0  1       0     0
# 887      0      112053  30.0000   B42  0  1       1     1
# 888      2  W./C. 6607  23.4500   NaN  0  1       1     1
# 889      0      111369  30.0000  C148  0  0       0     0
# 890      0      370376   7.7500   NaN  1  0       0     0
#
# [889 rows x 15 columns]

# %%
cd.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
cd.Male.value_counts()
# Out:
# 0    577
# 1    312
# Name: Male, dtype: int64

# %%
cd.Female.value_counts()
# Out:
# 0    577
# 1    312
# Name: Female, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
cols = ['Name', 'Ticket', 'Cabin']
cd = cd.drop(cols, axis=1)

# %%
cd
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Q  S  \
# 0              1         0       3    male  22.0      1      0   7.2500  0  1
# 1              2         1       1  female  38.0      1      0  71.2833  0  0
# 4              5         0       3    male  35.0      0      0   8.0500  0  1
# 5              6         0       3    male   NaN      0      0   8.4583  1  0
# 6              7         0       1    male  54.0      0      0  51.8625  0  1
# ..           ...       ...     ...     ...   ...    ...    ...      ... .. ..
# 886          887         0       2    male  27.0      0      0  13.0000  0  1
# 887          888         1       1  female  19.0      0      0  30.0000  0  1
# 888          889         0       3  female   NaN      1      2  23.4500  0  1
# 889          890         1       1    male  26.0      0      0  30.0000  0  0
# 890          891         0       3    male  32.0      0      0   7.7500  1  0
#
#      Female  Male
# 0         0     0
# 1         1     1
# 4         0     0
# 5         0     0
# 6         0     0
# ..      ...   ...
# 886       0     0
# 887       1     1
# 888       1     1
# 889       0     0
# 890       0     0
#
# [889 rows x 12 columns]

# %%
cd = cd.dropna()
# missing row having missing values

# %%
cd
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Q  S  \
# 0              1         0       3    male  22.0      1      0   7.2500  0  1
# 1              2         1       1  female  38.0      1      0  71.2833  0  0
# 4              5         0       3    male  35.0      0      0   8.0500  0  1
# 6              7         0       1    male  54.0      0      0  51.8625  0  1
# 7              8         0       3    male   2.0      3      1  21.0750  0  1
# ..           ...       ...     ...     ...   ...    ...    ...      ... .. ..
# 885          886         0       3  female  39.0      0      5  29.1250  1  0
# 886          887         0       2    male  27.0      0      0  13.0000  0  1
# 887          888         1       1  female  19.0      0      0  30.0000  0  1
# 889          890         1       1    male  26.0      0      0  30.0000  0  0
# 890          891         0       3    male  32.0      0      0   7.7500  1  0
#
#      Female  Male
# 0         0     0
# 1         1     1
# 4         0     0
# 6         0     0
# 7         0     0
# ..      ...   ...
# 885       1     1
# 886       0     0
# 887       1     1
# 889       0     0
# 890       0     0
#
# [712 rows x 12 columns]

# %%
cd = cd.drop(['Pclass', 'Sex'], axis=1)
# droping unwanted columns

# %%
cd
# Out:
#      PassengerId  Survived   Age  SibSp  Parch     Fare  Q  S  Female  Male
# 0              1         0  22.0      1      0   7.2500  0  1       0     0
# 1              2         1  38.0      1      0  71.2833  0  0       1     1
# 4              5         0  35.0      0      0   8.0500  0  1       0     0
# 6              7         0  54.0      0      0  51.8625  0  1       0     0
# 7              8         0   2.0      3      1  21.0750  0  1       0     0
# ..           ...       ...   ...    ...    ...      ... .. ..     ...   ...
# 885          886         0  39.0      0      5  29.1250  1  0       1     1
# 886          887         0  27.0      0      0  13.0000  0  1       0     0
# 887          888         1  19.0      0      0  30.0000  0  1       1     1
# 889          890         1  26.0      0      0  30.0000  0  0       0     0
# 890          891         0  32.0      0      0   7.7500  1  0       0     0
#
# [712 rows x 10 columns]
